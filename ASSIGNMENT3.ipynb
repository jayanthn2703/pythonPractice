# %%
string = "learning pytho is simple"
length_string=len(string)

# %%
string = "learning pytho is simple"
length_string=len(string)
print(string)
print(length_string)
# Out:
# learning pytho is simple
# 24

# %%
#given a string convert it into uppercase and lowercase
s="learning pytho is simple"
print(s.lower())
print(s.upper())
# Out:
# learning pytho is simple
# LEARNING PYTHO IS SIMPLE

# %%
s="learning pytho is simple"
v="aeiouAEIOU"
count=0
for i in s:
    if i in v:
        count+=1
print(count)
# Out:
# 7

# %%
#palindrome
string="madam"
palendrome=string[::-1]
if palendrome==string:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
#count number of words in sentence
s="learning pytho is simple"
count_string=len(s.split())
print(count_string)
# Out:
# 4

# %%
s="learning pytho is simple"
replaced =s.replace(' ','_')
print(replaced)
# Out:
# learning_pytho_is_simple

# %%
s="learning python is simple"
