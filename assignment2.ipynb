# %%
import math
radius = 5.5
area = math.pi*radius**2
print(f"the area of the circle of radius:'{radius}'is'{area}'")
# Out:
# the area of the circle of radius:'5.5'is'95.03317777109125'

# %%
### Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577
num=[3.14, 2.718, 1.618, 0.577]
average=sum(num)/len(num)
average
# Out:
# 2.01325

# %%
### Question 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)
F=98.6
C=(F-32)*5/9
C
# Out:
# 37.0

# %%
# Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years
Principal_amount=1000
Rate_interest=5.5
time=3
Final_amount=Principal_amount*(1+Rate_interest/100)**time
compund_interest=Final_amount-Principal_amount
compund_interest
# Out:
# 174.24137499999983

# %%
#### Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2
import math
a=3.5
b=4.2
hypot=math.sqrt(a**2+b**2)
print(hypot)
type(hypot)
# Out:
# 5.4671747731346585
# float

# %%
# Question 5: Calculate the volume of a sphere with radius 7.8
import math
r=7.8
volume=(4/3)*math.pi*r**3
volume
# Out:
# 1987.798769261791

# %%
#### Question 6: Round 3.14159 to 3 decimal places
num=3.13159
rounded_num=round(num,3)
rounded_num
# Out:
# 3.132

# %%
### Question 7: Calculate the percentage: 45 out of 67
a =45
b =67
percentage=(a/b)*100
percentage
# Out:
# 67.16417910447761

# %%
### Question 8: Find the square root of 23.456
import math
num=23.456
sqaure_root=math.sqrt(23.456)
sqaure_root
# Out:
# 4.843139477652899

# %%
### Question 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years
Princi=2500
Rate=6.5
Time=2.5
simple_interest=(Princi*Rate*Time)/100
simple_interest
# Out:
# 406.25

# %%
### Question 10: Convert 45.7 degrees to radians
import math
Degree=45.7
Radians=Degree*(math.pi/180)
Radians
# Out:
# 0.7976154681614086
