# %%
## Question 1: Calculate the product of first 10 natural numbers
num=1
for i in range (1,11):
    num*=i
print(num)
# Out:
# 3628800

# %%
# Question 2: Find the remainder when 156 is divided by 7
divisor=157
divident=7
remainder= divisor % divident
print(remainder)
# Out:
# 3

# %%
# Question 3: Calculate the square of 25
num = int(input("enter yoour number"))
square_root= num**2
print("sqaure root of",num,"is",square_root)
# Out:
# sqaure root of 95 is 9025

# %%
# Question 4: Find the cube root of 125
num = int(input("enter the number"))
cube_root=num**3
print(cube_root)
# Out:
# 614125

# %%
# Question 5: Calculate the sum of digits in number 12345
import math
sum=0
num='12345'
for i in str(num):
    sum+=int(i)
print(sum)
# Out:
# 15

# %%
# Question 6: Check if 97 is a prime number
num=int(input("enter your number"))
if num<2:
    print(" not pirme")
elif num>2:
    for i in range(2,num):
        if num%i==0:
            print("not pirme")
            break

    else:
        print("prime")
# Out:
# prime

# %%
# Question 7: Find the factorial of 8
num=8
fact=1
for i in range(1,num+1):
    fact*=i
print(fact)
# Out:
# 40320

# %%
# Question 8: Calculate the average of numbers: 15, 23, 31, 42, 56
num = [15, 23, 31, 42, 56]
averag = sum(num)/len(num)
print(averag)
# Out:
# 33.4

# %%
# Question 9: Find the greatest common divisor (GCD) of 48 and 36
import math

print("GCD is:", math.gcd(48, 36))
# Out:
# GCD is: 12

# %%
# Question 10: Calculate the sum of first 20 odd numbers
n = 20 
print("Sum of first 20 odd numbers:", n * n)
