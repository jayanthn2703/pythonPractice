# %%
##print("Question 1: Reverse the string 'Python Programming'")
stri = "python programming"
print(stri[::-1])
# Out:
# gnimmargorp nohtyp

# %%
##Check if "racecar" is a palindrome
s="racecar"
reverse=s[::-1]
print(reverse)
if s==reverse:
    print("true it is a palindrome")
else:
    print("no")
# Out:
# racecar
# true it is a palindrome

# %%
### Question 3: Count the number of words in "Python is a great programming language"
s="Python is a great programming language"
split_word=s.split(" ")

word=len(split_word)
print(f"the number of words in the given string is:{word}")
# Out:
# the number of words in the given string is:6

# %%
#### Question 4: Convert "hello world" to title case
s="hello word Python is a great programming languag"
titled_sent=s.title()
titled_sent
# Out:
# 'Hello Word Python Is A Great Programming Languag'

# %%
### Question 5: Find the length of string "Data Science"
s="Data Science"
lengt_s=len(s)
print(lengt_s)
# Out:
# 12

# %%
#### Question 6: Replace all spaces with underscores in "Machine Learning"
s="Machine Learning is important"
replace_s=s.replace(" ","_")
print(replace_s)
# Out:
# Machine_Learning_is_important

# %%
#### Question 7: Check if "python" is in "Python Programming Language"
str="Python Programming Language"
split_s=str.split()
for i in split_s:
    if "python" in split_s:
        print("true")
        break
else:
    print("false")
# Out:
# false

# %%
#### Question 8: Extract the first 5 characters from "Artificial Intelligence"
s="Artificial Intelligence"
print(s[:5])
# Out:
# Artif

# %%
#### Question 9: Convert "UPPERCASE" to lowercase
s="UPPERCASE"
lower_case=s.lower()
print(lower_case)
# Out:
# uppercase

# %%
#### Question 10: Remove all vowels from "Computer Science"
s="Computer Science"
vowels="aeiouAEIOU"
result=''
for i in s:

    if i not in vowels:
        result+=i
print(result)
# Out:
# Cmptr Scnc

# %%
s="computer science"
vowels="aeiou"
result=""
for i in s:
    if i not in vowels:
        result+=i
print(result)
# Out:
# cmptr scnc

# %%
#### Question 11: Find the most frequent character in "mississippi"
text="mississippi"
max_num = max(set(text),key=text.count)
print("max number is:",max_num)
# Out:
# max number is: s

# %%
### Question 12: Check if two strings are anagrams: "listen" and "silent"
s1="silent"
s2="listen"
if sorted(s1)==sorted(s2):
    print("it is a alagram")
else:
    print("it isnot a allgaram")
# Out:
# it is a alagram

# %%
### Question 13: Capitalize first letter of each word in "python programming language"
s="python programming language"
sent_ence=s.title()
print(sent_ence)
# Out:
# Python Programming Language

# %%
#### Question 14: Count consonants in "Hello World"
string="Hello World"
vowels="aeiou"
result=0
for i in string:
    if i.isalpha() and i.lower() not in vowels:
        result+=1
print(result)
# Out:
# 7

# %%
#### Question 15: Find the longest word in "Python is a programming language"
str="Python is a programming language"
sentance_a=str.split()
max_len=sentance_a[0]
for i in sentance_a:
    if len(i)>len(max_len):
        max_len=i
print(max_len)
# Out:
# programming

# %%
### Question 16: Remove all punctuation from "Hello, World! How are you?"
import string
st="Hello, World! How are you?"
remove=""
for ch in st:
    if ch not in string.punctuation:
        remove+=ch
print(remove)
# Out:
# Hello World How are you

# %%
#### Question 17: Check if string starts with "Python"
strin=input("enter your string:")
starts_check=strin.startswith("Python")
if starts_check==True:
    print("it starts with python")
else:
    print("no it doesnt starts with python")
# Out:
# no it doesnt starts with python

# %%
#### Question 18: Find the index of first occurrence of 'o' in "Hello World"
text = "Hello World"
index=text.find('o')
print(index)
# Out:
# 4

# %%
#### Question 19: Split string "apple,banana,orange" by comma
str="apple,banana,orange"
comma=str.replace(","," ")
print(comma)
# Out:
# apple banana orange

# %%
####Question  20: Join list ['Python', 'is', 'awesome'] with spaces
str='Python', 'is', 'awesome'
join=" ".join(str)
print(join)
# Out:
# Python is awesome

# %%
#### Question 21: Check if string contains only digits: "12345"
str="12345"
check=str.isdigit()
print(check)
# Out:
# True

# %%
#### Question 22: Check if string contains only letters: "HelloWorld"
str="hello world"
check=str.isalpha()
print(check)
# Out:
# False

# %%
#### Question 23: Convert "hello world" to "hElLo WoRlD" (alternating case)
str="hello world"
result=""
for i,char in enumerate(str):
    if char.isalpha():
        if i%2==0:
            result+=char.lower()
        else:
            result+=char.upper()
print(result)
# Out:
# hElLowOrLd

# %%
### Question 24: Find all positions of 'a' in "banana"
str="banana"
positions=[]
for i,char in enumerate(str):
    if char=='a':
        positions.append(i)
print(positions)
# Out:
# [1, 3, 5]

# %%
# Question 25: Remove leading and trailing whitespace from "  Hello World  "
str="  Hello World  "
space=str.strip()
print(space)
# Out:
# Hello World

# %%
# Question 26: Check if string ends with "ing": "programming"
str="programming"
check=str.endswith("ing")
print(check)
# Out:
# True

# %%
# Question 27: Replace first occurrence of 'o' with '0' in "Hello World"
str="Hello World"
change=str.replace("o","O",1)
print(change)
# Out:
# HellO World

# %%
# Question 28: Find the shortest word in "Python is a programming language"
str="Python is a programming language"
split_str=str.split()
min_str=min(split_str,key=len)
print(min_str)
# Out:
# a

# %%
# Question 29: Count words that start with 'p' in "Python programming is powerful"
str="Python programming is powerful"
split_str=str.split()
count=0
for i in split_str:
    if i.startswith("p"):
        count+=1
print(count)
# Out:
# ['Python', 'programming', 'is', 'powerful']
# 2

# %%
# Question 30: Reverse words in "Hello World Python"
s="Hello World Python"
spli_str=s.split()
revers=print(spli_str[::-1])
# Out:
# ['Python', 'World', 'Hello']

# %%
# Question 30: Reverse words in "Hello World Python"
str="Hello World Python"
reverse="_".join(str.split()[::-1])
reverse
# Out:
# 'Python_World_Hello'

# %%
# Question 31: Check if string is a valid email format: "user@example.com"
gmail="user@example.com"
if "@" in gmail and "." in gmail:
    print(f"{gmail} is valid")
else:
    print("gmail is invalid")
# Out:
# user@example.com is valid

# %%
# Question 32: Extract domain from "https://www.example.com/path"
domain="https://www.example.com/path"
split_domain=domain.split("//")[1].split("/")[0]
print(split_domain)
# Out:
# www.example.com

# %%
# Question 33: Count lines in multi-line string
text="""good morning
have a nice day
had your breakfast"""
count=0
splitting=text.split("\n")
for i in splitting:
    count+=1
print(f"the number of lines is:{count}")
# Out:
# the number of lines is:3

# %%
# Question 34: Find common characters between "hello" and "world"
t1="hello"
t2="world"
words=""
for i in t1:
    if i in t2 and i not in words:
        words+=i
print(f"the common numbers are {words}")
# Out:
# the common numbers are lo

# %%
# Question 35: Check if string is a valid phone number: "+1-555-123-4567"
number="+1-555-123-4567"
parts=number.split("-")
if parts[0].startswith("+") and parts[1].isdigit() and parts[2].isdigit() and parts[3].isdigit():
    print("valid number")
else:
    print("invalid number")
# Out:
# valid number

# %%
# Question 36: Extract numbers from "abc123def456ghi789"
text="abc123def456ghi789"
numbers=""
for i in text:
    if i.isdigit():
        numbers+=i
print(numbers)
# Out:
# 123456789

# %%
# Question 37: Convert "snake_case" to "camelCase"
t1="snake_case"
parts=t1.split("_")
camel=parts[0] + "".join(word.capitalize() for word in parts[1:])
print(camel)
# Out:
# snakecase

# %%
# Question 38: Check if string is a valid palindrome ignoring case: "A man a plan a canal Panama"
text="A man a plan a canal Panama"
case_removing=text.replace(" ","").lower()
if case_removing[::-1]==case_removing:
        print("it is a palindrome")
else:
    print("it is not a palindrome")
# Out:
# it is not a palindrome

# %%
# Question 39: Find the most common word in "the quick brown fox jumps over the lazy dog"
text="the quick brown fox jumps over the lazy dog"
common=""
words=""
split_word=text.split()
for i in split_word:
    common+=i
    for i in split_word:
        if i==common:
            words+=i
print(words)
# Out:
# thethe

# %%
# Question 40: Generate acronym from "National Aeronautics and Space Administration"
